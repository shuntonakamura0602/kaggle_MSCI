# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import scipy.sparse
from sklearn.preprocessing import MinMaxScaler
import scipy.sparse
from sklearn.preprocessing import MaxAbsScaler

# %% [markdown]
# # conversion functions

# %%
all_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_original_all_multi_inputs_values.sparse.npz')

# %%
#scaler = MaxAbsScaler()
all_inputs = np.sqrt(all_inputs)

# %%
train_inputs = all_inputs[:105942,:]
test_inputs = all_inputs[105942:,:]

# %%
train_inputs.shape,test_inputs.shape
# Out:
# ((105942, 228942), (55935, 228942))

# %%
scipy.sparse.save_npz("/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_sqrt_train_multi_inputs_values.sparse", train_inputs)

# %%
scipy.sparse.save_npz("/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_sqrt_test_multi_inputs_values.sparse", test_inputs)
