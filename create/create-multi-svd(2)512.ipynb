# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
N_COMPONENTS = 512

# %%
! pip install tables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os, gc, pickle, datetime, scipy.sparse
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD,PCA
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from cycler import cycler
from IPython.display import display
import os
import scipy.sparse
from sklearn.decomposition import SparsePCA

# %% [markdown]
# ## original

# %%
# %%time
train_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_original_train_multi_inputs_values.sparse.npz')
train_targets = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_multi_targets_values.sparse.npz')
# Out:
# CPU times: user 1min 4s, sys: 11.8 s, total: 1min 16s
# Wall time: 1min 20s

# %%
train_inputs.shape,train_targets.shape
# Out:
# ((105942, 228942), (105942, 23418))

# %%
# %%time
pca = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_inputs = pca.fit_transform(train_inputs)
pca2 = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_targets = pca2.fit_transform(train_targets)
# Out:
# CPU times: user 1h 21min 43s, sys: 1min 27s, total: 1h 23min 11s
# Wall time: 1h 19min 33s

# %%
train_inputs.shape,train_targets.shape
# Out:
# ((105942, 512), (105942, 512))

# %%
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/pca_Varianced_original_train_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_Varianced_original_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_inputs, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/pca_Varianced_original_target_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca2, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Y_Varianced_original_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_targets, p)

# %% [markdown]
# ## minmax

# %%
# %%time
train_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_minmax_train_multi_inputs_values.sparse.npz')
# Out:
# CPU times: user 43.6 s, sys: 9.52 s, total: 53.1 s
# Wall time: 1min 11s

# %%
# %%time
pca = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_inputs = pca.fit_transform(train_inputs)
# Out:
# CPU times: user 58min 22s, sys: 58.5 s, total: 59min 21s
# Wall time: 56min 45s

# %%
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/pca_Varianced_minmax_train_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_Varianced_minmax_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_inputs, p)

# %% [markdown]
# ## sqrt

# %%
# %%time
train_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_sqrt_train_multi_inputs_values.sparse.npz')
# Out:
# CPU times: user 41.1 s, sys: 2.97 s, total: 44.1 s
# Wall time: 52.2 s

# %%
# %%time
pca = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_inputs = pca.fit_transform(train_inputs)
# Out:
# CPU times: user 1h 7min 5s, sys: 1min, total: 1h 8min 5s
# Wall time: 1h 5min 24s

# %%
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/pca_Varianced_sqrt_train_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_Varianced_sqrt_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_inputs, p)

# %% [markdown]
# ## standard

# %%
# %%time
train_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_standard_train_multi_inputs_values.sparse.npz')
# Out:
# CPU times: user 40.4 s, sys: 2.22 s, total: 42.6 s
# Wall time: 56 s

# %%
# %%time
pca = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_inputs = pca.fit_transform(train_inputs)
# Out:
# CPU times: user 1h 6min 32s, sys: 59.5 s, total: 1h 7min 31s
# Wall time: 1h 4min 53s

# %%
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/pca_Varianced_standard_train_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_Varianced_standard_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_inputs, p)

# %% [markdown]
# ## log

# %%
# %%time
train_inputs = scipy.sparse.load_npz('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/Varianced_log_train_multi_inputs_values.sparse.npz')
# Out:
# CPU times: user 39.9 s, sys: 3.39 s, total: 43.3 s
# Wall time: 51.8 s

# %%
# %%time
pca = TruncatedSVD(n_components=N_COMPONENTS, random_state=42)
train_inputs = pca.fit_transform(train_inputs)
# Out:
# CPU times: user 48min 18s, sys: 54.5 s, total: 49min 12s
# Wall time: 46min 45s

# %%
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/svd_svd_log_Varianced_train_multi_{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(pca, p)
with open(f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/svd_log_Varianced_train_multi_inputs{N_COMPONENTS}.pkl", 'wb') as p:
    pickle.dump(train_inputs, p)
