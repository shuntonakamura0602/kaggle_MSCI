# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import scipy.sparse
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # conversion functions

# %%
original_train = pd.read_hdf("/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/train_cite_inputs.h5")

# %%
original_test = pd.read_hdf('/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/test_cite_inputs.h5')

# %%
original_train.shape,original_test.shape
# Out:
# ((70988, 22050), (48663, 22050))

# %%
original_all = pd.concat([original_train,original_test])
original_all.shape
# Out:
# (119651, 22050)

# %%
original_col = original_all.columns

# %%
scaler = StandardScaler()
original_all = scaler.fit_transform(original_all)

# %%
original_train = original_all[:70988]
original_test = original_all[70988:]

# %%
original_train.shape,original_test.shape
# Out:
# ((70988, 22050), (48663, 22050))

# %%
original_train = pd.DataFrame(data=original_train,columns=original_col)

# %%
original_test = pd.DataFrame(data=original_test,columns=original_col)

# %%
original_train.to_hdf("/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/standard_train_cite_inputs.h5",'key',mode='w')

# %%
original_test.to_hdf("/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/dataset/standard_test_cite_inputs.h5",'key',mode='w')
