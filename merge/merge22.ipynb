# %% [markdown]
# # calc cv

# %%
MULTI_NAME = 'keras4'
CITE_NAME = 'keras35'

# %%
multi_pri_cv = 0.60613
cite_pri_cv = 0.88674
print(f'all_pri_cv:{cite_pri_cv*0.712 + multi_pri_cv*0.288:.5f}')
# Out:
# all_pri_cv:0.80592

# %%
# cite weights 0.743
# multi weights 0.257
multi_pub_cv = 0.66821
cite_pub_cv = 0.89419
print(f'all_pub_cv:{cite_pub_cv*0.712 + multi_pub_cv*0.288:.5f}')
# Out:
# all_pub_cv:0.82911

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# # merge csv

# %%
CITE_PATH = f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/cite_sub/{CITE_NAME}.csv"
MULTI_PATH = f"/content/drive/MyDrive/Colab Notebooks/kaggle/MSCI/multi_sub/{MULTI_NAME}.csv"
SUB_NAME = f"{CITE_NAME}+{MULTI_NAME}.csv"

# %%
cite_submission = pd.read_csv(CITE_PATH)
cite_submission = cite_submission.set_index("row_id")
cite_submission = cite_submission["target"]

# %%
multi_submission = pd.read_csv(MULTI_PATH)
multi_submission = multi_submission.set_index("row_id")

# %%
multi_submission.target[multi_submission.target.isnull()] = cite_submission[multi_submission.target.isnull()]

# %%
multi_submission.isnull().any()
# Out:
# target    False
# dtype: bool

# %% [markdown]
# # to_csv

# %%
#multi_submission.to_csv(SUB_PATH)

# %%
multi_submission.to_csv(SUB_NAME)

# %% [markdown]
# # sub to kaggle

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import json
f = open("/content/drive/MyDrive/Colab Notebooks/kaggle/kaggle.json", 'r')
json_data = json.load(f) 
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
# !kaggle competitions submit -c open-problems-multimodal -f keras35+keras4.csv -m ""
# Out:
# 100% 1.23G/1.23G [00:23<00:00, 55.8MB/s]
# Successfully submitted to Open Problems - Multimodal Single-Cell Integration
